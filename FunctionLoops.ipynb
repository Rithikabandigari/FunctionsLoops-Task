# %% [markdown]
# Problem 1: Mobile Recharge Validation System
#  Problem Statement
# Create a function to validate a mobile recharge request.
# Rules:
# Recharge amount must be ≥ ₹50
#
#
# Valid plans: 199, 299, 399, 599
#
#
# User should be allowed to retry if invalid

# %%
def mobile_recharge():
    valid_plans = [199, 299, 399, 599]
    while True:
        amount = int(input("Enter recharge amount: "))

        if amount < 50:
            print(" Minimum recharge amount is 50. Try again.")
        elif amount not in valid_plans:
            print(" Invalid plan. Available plans are:", valid_plans)
        else:
            print(f"Recharge of ₹{amount} successful!")
            break
mobile_recharge()
# Out:
# Enter recharge amount: ₹299
# Recharge of ₹299 successful!

# %% [markdown]
# Problem 2: Inventory Reorder Alert System
# Problem Statement
# Given a dictionary of products and stock quantities:
# Print Reorder Alert if stock < 15
#
#
# Print Stock OK otherwise
#
#
# Real-Time Use
# Warehouse systems
#
#
# Retail management
#
#
# Hint
# Use function
#
#
# Use for loop on dictionary

# %%
stock={'sunscreens':12,'bodylotion':20,'lipbalm':9,'lipstick':17}
for products,values in stock.items():
  if values<15:
    print(f"{products} out of Stock")
  elif values>15:
    print(f"{products} stock ok")
# Out:
# sunscreens out of Stock
# bodylotion stock ok
# lipbalm out of Stock
# lipstick stock ok

# %%
def result():
  sub=int(input("Enter the number of subjects:"))
  lst=[]
  for i in range (1,sub+1):
    marks=int(input(f"Enter your marks for subject {i}:"))
    lst.append(marks)
  avg=sum(lst)/len(lst)
  print("Average :",avg)
  if avg>=50:
    print("pass")
  else:
    print("Fail")

# %%
result()
# Out:
# Enter the number of subjects:3
# Enter your marks for subject 1:98
# Enter your marks for subject 2:97
# Enter your marks for subject 3:89
# Average : 94.66666666666667
# pass

# %% [markdown]
# Problem 4: Cab Fare Estimator with Retry Option
# Problem Statement
# Create a cab fare calculator:
# Base fare = ₹50
#
#
# ₹12 per km
#
#
# Peak hour → 25% extra
#
#
# Allow retry using while loop

# %%
def fare():
    base = 50
    per_km = 12
    while True:
        km = float(input("Enter the distance in km: "))
        hour = input("Enter the hour (peak/normal): ").lower()
        if hour == 'normal':
            price = base + km * per_km
            print("Total Fare: ", price)
            break
        elif hour == 'peak':
            price = (base + km * per_km) * 1.25
            print("Total Fare (Peak Hour): ", price)
            break
        else:
            print("Invalid input for hour. Please enter 'peak' or 'normal'. Try again.")
fare()
# Out:
# Enter the distance in km: 4
# Enter the hour (peak/normal): normal
# Total Fare:  98.0

# %% [markdown]
# Problem 5: Employee Attendance Eligibility Checker
# Problem Statement
# Create a function that:
# Accepts attendance list ("P", "A")
#
#
# Calculates attendance percentage
#
#
# Returns Eligible if ≥ 75% else Not Eligible
#
#
# Real-Time Use
# HR payroll systems
#
#
# Internship tracking
#
#
#  Hint
# Use loop to count present days
#
#
# Use return statement

# %%
def check_attendance(attendance):
    present = 0
    for day in attendance:
        if day == "P":
            present += 1
    percentage = (present / len(attendance)) * 100
    if percentage >= 75:
        return f"Eligible (Attendance: {percentage:.2f}%)"
    else:
        return f"Not Eligible (Attendance: {percentage:.2f}%)"
check_attendance(["P","A","P","P","P"])
# Out:
# 'Eligible (Attendance: 80.00%)'

# %% [markdown]
# Problem 6: Password Strength Checker
# Problem Statement
# Create a function to check password strength.
# Rules:
# Minimum length = 8
#
#
# Must contain at least one digit
#
#
# Must contain at least one special character (@#$)

# %%
def password_strength(password):
    if len(password) < 8:
        return "Weak Password: Must be at least 8 characters long"

    has_digit = False
    has_special = False
    special_chars = "@#$"

    for ch in password:
        if ch.isdigit():
            has_digit = True
        if ch in special_chars:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password: Must contain at least one digit and one special character (@, #, $)"

# %%
password_strength('leo123')
# Out:
# 'Weak Password: Must be at least 8 characters long'
